# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv("Oxfam_Dataset.csv")

# %%
data.sample(10)
# Out:
#                       Type          Colour                        Brand  \
# 38408                  NaN           Brown                        OASIS
# 5770                   NaN            Pink  M&amp;S Marks &amp; Spencer
# 27681    Knee length dress           Black                  Phase Eight
# 19755                Short           Black   Redherring Special Edition
# 25999  Smart jacket / coat            Pink             Pringle Scotland
# 13882             Necklace       Metallics                    Unbranded
# 37757                  NaN           Black  M&amp;S Marks &amp; Spencer
# 21046                  NaN  Multi-coloured                 Laura Ashley
# 24230                  NaN           Black                 Great Plains
# 28128    Knee length dress             Red                Second Female
#
#                   Exact Colour                                  Title  \
# 38408          Chocolate brown                                    NaN
# 5770                  Pink Mix                                    NaN
# 27681                      NaN                                    NaN
# 19755                      NaN                                    NaN
# 25999                    Peach                                    NaN
# 13882           Yellow Silver   Unbranded Yellow Ethnic Bead Necklace
# 37757                      NaN                                    NaN
# 21046                      NaN                                    NaN
# 24230  Black, pink &amp; cream                                    NaN
# 28128                     Wine                                    NaN
#
#                       Img name  \
# 38408  HD_101825865_01.jpg?v=1
# 5770   HD_101753069_01.jpg?v=1
# 27681  HD_101802953_01.jpg?v=1
# 19755  HD_101844733_01.jpg?v=1
# 25999  HD_101790644_01.jpg?v=1
# 13882  HD_200016851_01.jpg?v=1
# 37757  HD_101812754_01.jpg?v=1
# 21046  HD_101834988_01.jpg?v=1
# 24230  HD_101806547_01.jpg?v=1
# 28128  HD_101767118_01.jpg?v=1
#
#                                                  Img src
# 38408  https://yatra8exe7uvportalprd.blob.core.window...
# 5770   https://yatra8exe7uvportalprd.blob.core.window...
# 27681  https://yatra8exe7uvportalprd.blob.core.window...
# 19755  https://yatra8exe7uvportalprd.blob.core.window...
# 25999  https://yatra8exe7uvportalprd.blob.core.window...
# 13882  https://yatra8exe7uvportalprd.blob.core.window...
# 37757  https://yatra8exe7uvportalprd.blob.core.window...
# 21046  https://yatra8exe7uvportalprd.blob.core.window...
# 24230  https://yatra8exe7uvportalprd.blob.core.window...
# 28128  https://yatra8exe7uvportalprd.blob.core.window...

# %%
# dropping img src since we don't need both img src and Img name

data = data.drop(columns=['Img src'])

# %%
#returns (rows, columns)

data.shape
# Out:
# (41281, 6)

# %%
data.isna().sum()
# Out:
# Type            14080
# Colour            634
# Brand             121
# Exact Colour    19892
# Title           34049
# Img name            0
# dtype: int64

# %%
# lising all unique types

data.Type.unique()
# Out:
# array(['Cardigan', nan, 'Other', 'Full length dress', 'Parka',
#        'Quilted jacket', 'Coat', 'Jacket', 'Hoodie', 'Long dress',
#        'Summer', 'Calf length', 'Sleeveless', 'Fleece jacket',
#        'School uniform', 'Leotard', 'Jeans', 'Dress /  gown',
#        'Body warmer', 'Tracksuit top', 'Knee length dress',
#        'Long sleeved shirt', 'Gilet', 'Wetsuit', 'Vintage', 'Jumper',
#        'Sleeveless top', 'Evening dress', 'Trainers', 'Slip-on shoes',
#        'Bikini', 'Trousers', 'Denim jacket', 'T-Shirt', 'Raincoat',
#        'Prom dress', 'Smock top', 'Polo shirt', 'One piece', 'Sweater',
#        'Boots', 'Knee length skirt', 'Bomber jacket', 'Mini skirt',
#        'Casual jacket / coat', 'Flat shoes', 'Hot pants', 'Trenchcoat',
#        'Patterned skirt', 'Leather jacket', 'Vest', 'Cargo pants',
#        'Jeggings / stretch trousers', 'Cropped trousers', 'Ballet',
#        'Blouse', 'Checked skirt', 'Short', 'Smock', 'Short sleeved shirt',
#        'Hooded top', 'Mini dress', 'Jeggings / stretch jeans',
#        'Pleated skirt', 'Gypsy skirt', 'Quilted coat', 'A-line skirt',
#        'Sandals', 'Overcoat', 'Strapless dress', 'Padded jacket',
#        'Dance shoes', 'Single breasted blazer', 'Long sleeved',
#        'Sweatshirt', 'All in one', 'Pullover', 'Hiking jacket',
#        'Surf shorts', 'Ski trousers', 'Waxed jacket', 'Tracksuit bottoms',
#        'Short sleeved T-shirt', 'Combats', 'Pyjamas', 'Deck shoes',
#        'Short sleeved', '3 piece suit', 'Football socks', 'Hi tops',
#        'Single breasted suit jacket', 'Cargo shorts', 'Football top',
#        'Plimsolls', 'Tie', 'Scarf', 'Chelsea / ankle boots', 'Lace-ups',
#        'Work boots', 'Double breasted blazer', 'Sports top', 'Wallet',
#        'Cowboy hat', 'Walking, hiking &amp; trail', 'Single breasted suit',
#        'Football', 'Belt', 'Loafers', 'Denim jeans', 'Beanie', 'Rugby top',
#        'Manbag', 'Smart jacket / coat', 'Chinos', 'Waistcoat',
#        'Tail coat suit jacket', 'Tail coat suit', 'Leather trousers',
#        'PVC trousers', 'Long sleeved T-shirt',
#        'Double breasted dinner suit', 'Single breasted dinner suit',
#        'Brogue', 'Baseball shoes', 'Slipper shoes', 'Ski suit',
#        'Cross body bag', 'Bow tie', 'Mittens', 'Moccasins',
#        'Sports Wristwatch', 'digital watch', 'Not specified', 'Shorts',
#        'Weekend Bag', 'Cuff links', 'Running shoes', 'Baseball cap',
#        'Briefs', 'Cravat', 'Rucksack', 'Flip flops', '3/4', 'Skate shoes',
#        'Peaked cap', 'Driving gloves', 'Slip ons', 'Bowler hat',
#        'Cuff Links ', 'Outfit', 'Biker boots', 'Bush hat',
#        'Fleece jackets', 'Coin purse', 'Woolie hat', 'Boxers', 'Gloves',
#        'Leather coat', 'Suitcase', 'Cuff Links',
#        'Double breasted suit jacket', 'Robe', 'Desert boots',
#        'Duffle coat', 'Tie Pin', 'Snow &amp; winter boots', 'Trilby',
#        'Long bottoms', 'Wrist watches', 'Waxed coat', 'Backpack',
#        'Double breasted suit', 'Tank top', 'Tweed jacket', 'College scarf',
#        'Trunks', 'Cufflinks', 'Golf shoes', 'Tablewear', 'Make up bag',
#        'Board', 'Salopettes', 'Strapped sandals', 'Motorcycle trousers',
#        'Sports sandals', 'Sports gloves', 'Cowboy boots',
#        'Hiking trousers', 'Mixed items', 'Kilt', 'Sunglasses', 'Cuff link',
#        'Ascot', 'Laptop bag', 'Briefcase', 'Swimming shorts',
#        'Smokers pipes', 'Cuff-Links ', 'Long / riding boots', 'Rugby',
#        'Vintage skirt', 'Purse', 'Necklace', 'Handbag',
#        'Calf length skirt', 'Skirt suit', 'Evening', 'Cocktail dress',
#        'Tote bag', 'Handkerchief skirt', 'Shoulder bag',
#        'Halter-neck dress', 'Long skirt', 'Pencil skirt', 'Heeled shoes',
#        'Cap sleeved T-shirt', 'Clutch bag', 'Mini bag',
#        'Ladies dress watch', 'Basque', 'Lace-up shoes', 'Full length',
#        'Wraparound top', 'Halter-neck top', 'Silver ring', 'Court shoes',
#        'Batwing top', 'Slingbacks', 'Pendant', 'Chain', 'Blazer', 'Shirt',
#        'Wrap around', 'Evening gloves', 'Asymmetrical dress',
#        'Dressing gown', 'Mules', 'Top handle bag', 'Dress', 'Jumpsuit',
#        'Grab bag', 'Fascinator', 'Wrap around dress', 'Shopper bag',
#        'Bustier', 'Trouser suit', 'Bra', 'Ladies bracelet wristwatch',
#        'Ladies wistwatch', 'Poncho', 'Watch', '3 piece skirt suit',
#        'Shrug', 'Bolero', 'Playsuit', 'Pashmina', 'Messenger bag',
#        'Suit jacket', 'Sweat pants', 'Wedding dress', 'Ring',
#        'Peep toe shoes', 'Cropped jeans', 'Full skirt wedding dress',
#        'Tube', 'Harem pants', 'Leggings', 'Halter-neck', 'Culottes',
#        'Nighty', 'Boob tube', 'Brogues', 'Slippers', 'Baguette handbag',
#        'Corset', 'Shawl', 'Wedding hat', 'Bracelet', 'Hobo bag',
#        'Ladies wristwatch', 'Sac', 'Camisole', 'Sporty shorts',
#        'Wristwatch', 'Boiler suit', 'Puffball skirt',
#        'Long skirt / trousers', 'Weekend bag', 'Tulip skirt', 'High waist',
#        'Chemise', 'Short jacket', '3 piece trouser suit',
#        'Wristwatch &amp; Bracelet', 'Balaclava', 'Pedal pushers', '.',
#        'Babydoll', 'watch', 'Analogue', 'Catsuit', 'Quartz Dress/Fashion',
#        'Quartz Watch', 'Gold coloured quartz watch', 'Panama', 'Kimono',
#        'Cosmetic bag', 'Jodhpurs', 'Dress Watch', 'wristwatch',
#        'Handmade Enamel Costume Ring', 'Cape', 'Tracksuit',
#        'ladies wristwatch', 'Parachute pants', 'Thong', 'Hats', 'Shoes',
#        'Suit / outfit', 'Wrist watch', 'Flared / kick flare jeans'], dtype=object)

# %%
# list of all types that we want to remove from the dataset

lstToDel = ['Summer', 'School uniform', 'Leotard', 'Body warmer', 'Wetsuit', 'Slip-on shoes', 
            'Bikini', 'Prom dress', 'Boots', 'Flat shoes', 'Ballet', 'Sandals', 'Dance shoes', 
            'All in one', 'Pyjamas', 'Deck shoes', 'Football socks', 'Plimsolls', 'Tie', 'Scarf', 
            'Chelsea / ankle boots', 'Lace-ups', 'Work boots', 'Wallet', 'Cowboy hat', 
            'Walking, hiking &amp; trail', 'Football', 'Belt', 'Loafers', 'Beanie', 'Rugby top', 
            'Manbag', 'Brogue', 'Baseball shoes', 'Slipper shoes', 'Ski suit', 'Cross body bag', 
            'Bow tie', 'Mittens', 'Moccasisns', 'Sports Wristwatch', 'digital watch', 
            'Weekend Bag', 'Cuff links', 'Running shoes', 'Baseball cap', 'Briefs', 'Cravat', 
            'Rucksack', 'Flip flops', '43924', 'Skate shoes', 'Peaked cap', 'Driving gloves', 
            'Slip ons', 'Bowler hat', 'Cuff links', 'Outfit', 'Biker boots', 'Bush hat', 
            'Coin purse', 'Woolie hat', 'Boxers', 'Gloves', 'Cuff Links', 'Robe', 'Desert boots', 
            'Tie Pin', 'Snow &amp; winter boots', 'Trilby', 'Wrist watches', 'Backpack', 
            'College scarf', 'Trunks', 'Golf shoes', 'Tablewear', 'Make up bag', 'Board', 
            'Salopettes', 'Strapped sandals', 'Motorcycle trousers', 'Sports sandals', 
            'Sports gloves', 'Cowboy boots', 'Hiking trousers', 'Mixed items', 'Kilt', 
            'Sunglasses', 'Cuff link', 'Ascot', 'Laptop bag', 'Briefcase', 'Swimming shorts', 
            'Smokers pipes', 'Cuff-Links', 'Long / riding boots', 'Rugby', 'Cufflinks', 'Purse', 
            'Handbag', 'Tote bag', 'Shoulder bag', 'Heeled shoes', 'Clutch bag', 'Necklace', 
            'Mini bag', 'Ladies dress watch', 'Basque', 'Lace-up shoes', 'Silver ring', 
            'Court shoes', 'Batwing top', 'Slingbacks', 'Pendant', 'Chain', 'Evening gloves', 
            'Mules', 'Top handle bag', 'Grab bag', 'Fascinator', 'Shopper bag', 'Bustier', 'Bra', 
            'Ladies bracelet wristwatch', 'Ladies wistwatch', 'Watch', 'Shrug', 'Bolero', 
            'Pashmina', 'Messenger bag', 'Wedding dress', 'Ring', 'Peep toe shoes', 
            'Full skirt wedding dress', 'Tube', 'Nighty', 'Boob tube', 'Brogues', 'Slippers', 
            'Baguette handbag', 'Corset', 'Shawl', 'Wedding hat', 'Hobo bag', 'Ladies wristwatch', 
            'Sac', 'Wristwatch', 'Weekend bag', 'Chemise', 'Wristwatch &amp; Bracelet', 'Balaclava', 
            'Pedal pushers', 'Babydoll', 'watch', 'Analogue', 'Catsuit', 'Quartz Dress/Fashion', 
            'Quartz Watch', 'Gold coloured quartz watch', 'Panama', 'Kimono', 'Cosmetic bag', 
            'Jodhpurs', 'Dress Watch', 'wristwatch', 'Handmade Enamel Costume Ring', 'Cape', 
            'ladies wristwatch', 'Thong', 'Hats', 'Shoes', 'Wrist watch', 'Bracelet', 'Suitcase', 
            'One piece', 'Cuff Links ', 'Cuff-Links ', 'Football top', 'Cuff-Links', 'Ski trousers', 
            'Suit / outfit', 'Long bottoms', 'Tracksuit', 'Parachute pants', '.', 'High waist', 
            'Tail coat suit', 'Double breasted dinner suit', 'Camisole', 'Poncho', 
            'Long skirt / trousers', 'Moccasins', 'Tail coat suit jacket', 'Surf shorts', 
            'Handkerchief skirt', '3 piece skirt suit', 'Shorts', 'Dressing gown', 
            'Double breasted suit', 'Sporty shorts', '3 piece suit', '3/4', 'Halter-neck top', 
            'Halter-neck', 'Single breasted dinner suit', 'Trouser suit', 'Single breasted suit', 
            '3 piece trouser suit', 'Vintage', 'Trainers', 'Other', 'Not Specified', 
            'Tracksuit top', 'Tracksuit bottoms', 'Not specified']

# %%
# removing all rows that contain a value in the type that matches 
# to our list that we wanted to remove

before = data.Type.unique()
beforeLen = len(before)
print("Number of unique values in 'Type' before: ", beforeLen)

data = data[~data.Type.isin(lstToDel)]

after = data.Type.unique()
afterLen = len(after)
print("Number of unique values in 'Type' after: ", afterLen)

difference = beforeLen - afterLen
print("Difference is: ", difference)
# Out:
# Number of unique values in 'Type' before:  321
# Number of unique values in 'Type' after:  112
# Difference is:  209

# %%
# returns (rows, columns)

data.shape
# Out:
# (35380, 6)

# %%
data.Type.unique()
# Out:
# array(['Cardigan', nan, 'Full length dress', 'Parka', 'Quilted jacket',
#        'Coat', 'Jacket', 'Hoodie', 'Long dress', 'Calf length',
#        'Sleeveless', 'Fleece jacket', 'Jeans', 'Dress /  gown',
#        'Knee length dress', 'Long sleeved shirt', 'Gilet', 'Jumper',
#        'Sleeveless top', 'Evening dress', 'Trousers', 'Denim jacket',
#        'T-Shirt', 'Raincoat', 'Smock top', 'Polo shirt', 'Sweater',
#        'Knee length skirt', 'Bomber jacket', 'Mini skirt',
#        'Casual jacket / coat', 'Hot pants', 'Trenchcoat',
#        'Patterned skirt', 'Leather jacket', 'Vest', 'Cargo pants',
#        'Jeggings / stretch trousers', 'Cropped trousers', 'Blouse',
#        'Checked skirt', 'Short', 'Smock', 'Short sleeved shirt',
#        'Hooded top', 'Mini dress', 'Jeggings / stretch jeans',
#        'Pleated skirt', 'Gypsy skirt', 'Quilted coat', 'A-line skirt',
#        'Overcoat', 'Strapless dress', 'Padded jacket',
#        'Single breasted blazer', 'Long sleeved', 'Sweatshirt', 'Pullover',
#        'Hiking jacket', 'Waxed jacket', 'Short sleeved T-shirt', 'Combats',
#        'Short sleeved', 'Hi tops', 'Single breasted suit jacket',
#        'Cargo shorts', 'Double breasted blazer', 'Sports top',
#        'Denim jeans', 'Smart jacket / coat', 'Chinos', 'Waistcoat',
#        'Leather trousers', 'PVC trousers', 'Long sleeved T-shirt',
#        'Fleece jackets', 'Leather coat', 'Double breasted suit jacket',
#        'Duffle coat', 'Waxed coat', 'Tank top', 'Tweed jacket',
#        'Vintage skirt', 'Calf length skirt', 'Skirt suit', 'Evening',
#        'Cocktail dress', 'Halter-neck dress', 'Long skirt', 'Pencil skirt',
#        'Cap sleeved T-shirt', 'Full length', 'Wraparound top', 'Blazer',
#        'Shirt', 'Wrap around', 'Asymmetrical dress', 'Dress', 'Jumpsuit',
#        'Wrap around dress', 'Playsuit', 'Suit jacket', 'Sweat pants',
#        'Cropped jeans', 'Harem pants', 'Leggings', 'Culottes',
#        'Boiler suit', 'Puffball skirt', 'Tulip skirt', 'Short jacket',
#        'Flared / kick flare jeans'], dtype=object)

# %%
# sum of all types

data.Type.value_counts()
# Out:
# Jacket                         1713
# Trousers                       1501
# Knee length dress              1264
# Smart jacket / coat            1147
# Long sleeved                    988
# Casual jacket / coat            932
# Sleeveless                      852
# Jumper                          674
# Blouse                          669
# Jeans                           592
# Single breasted suit jacket     575
# Long sleeved shirt              567
# Cardigan                        486
# Mini dress                      466
# Cocktail dress                  462
# Sleeveless top                  402
# Knee length skirt               401
# T-Shirt                         394
# Short                           357
# Long dress                      354
# Calf length                     347
# Evening dress                   327
# Strapless dress                 324
# Mini skirt                      246
# Calf length skirt               245
# Evening                         228
# Single breasted blazer          219
# Short sleeved shirt             214
# Full length dress               210
# Pencil skirt                    205
#                                ...
# Gypsy skirt                      18
# Gilet                            17
# Wrap around                      16
# Long sleeved T-shirt             15
# Double breasted blazer           15
# Vintage skirt                    14
# Cropped jeans                    13
# Checked skirt                    12
# Leather coat                     11
# Quilted coat                     10
# Culottes                         10
# Harem pants                       7
# Parka                             7
# Combats                           6
# Hooded top                        5
# Duffle coat                       5
# Sweat pants                       5
# Tweed jacket                      4
# Short jacket                      4
# Fleece jackets                    4
# Puffball skirt                    4
# PVC trousers                      4
# Waxed jacket                      3
# Tulip skirt                       3
# Tank top                          2
# Hi tops                           2
# Waxed coat                        2
# Boiler suit                       2
# Flared / kick flare jeans         1
# Dress                             1
# Name: Type, Length: 111, dtype: int64

# %%
# consolidating types into other types
# replaceDict = [Type Before: Type After]

replaceDict = {"Flared / kick flare jeans": "Jeans",
               "Tank top": "Top",
               "Hi tops": "Top",
               "Boiler suit": "Jumpsuit",
               "Waxed coat": "Coat",
               "Waxed jacket": "Jacket",
               "Tulip skirt": "Skirt",
               "Puffball skirt": "Skirt",
               "Tweed jacket": "Jacket",
               "Fleece jackets": "Jacket",
               "PVC trousers": "Trousers",
               "Short jacket": "Jacket",
               "Hooded top": "Hoodie",
               "Duffle coat": "Coat",
               "Combats": "Trousers",
               "Parka": "Jacket",
               "Harem pants": "Pants",
               "Quilted coat": "Coat",
               "Culottes": "Trousers",
               "Leather coat": "Coat",
               "Checked skirt": "Skirt",
               "Cropped jeans": "Jeans",
               "Vintage skirt": "Skirt",
               "Double breasted blazer": "Blazer",
               "Wrap around": "Dress",
               "Gypsy skirt": "Skirt",
               "Leather trousers": "Trousers",
               "Jeggings / stretch jeans": "Jeggings",
               "Denim jacket": "Jacket",
               "Fleece jacket": "Jacket",
               "Sports top": "Top",
               "Hiking jacket": "Jacket",
               "Wraparound top": "Top",
               "Jeggings / stretch trousers": "Jeggings",
               "Quilted jacket": "Jacket",
               "Cap sleeved T-shirt": "T-shirt",
               "Suit jacket": "Jacket",
               "Wrap around dress": "Dress",
               "Double breasted suit jacket": "Jacket",
               "Pullover": "Sweater",
               "Denim jeans": "Jeans",
               "Patterned skirt": "Skirt",
               "Padded jacket": "Jacket",
               "Pleated skirt": "Skirt",
               "Playsuit": "Jumpsuit",
               "Dress /  gown": "Dress",
               "Single breasted blazer": "Blazer",
               "Long sleeved": "Long sleeved shirt",
               "Single breasted suit jacket": "Jacket",
               "Calf length": "Calf length dress",
               "Evening": "Evening dress",
               "Short sleeved": "Short sleeved shirt",
               "A-line skirt": "Skirt",
               "Full length": "Full length dress",
               "Halter-neck dress": "Dress",
               "Asymmetrical dress": "Dress",
               "Hot pants": "Pants",
               "Sweat pants": "Pants",
               "T-shirt": "T-Shirt"
}

# %%
for key, val in replaceDict.items():
    data['Type'] = data['Type'].replace(to_replace = key, value = val)

# %%
data.Type.value_counts()
# Out:
# Jacket                   2552
# Long sleeved shirt       1555
# Trousers                 1540
# Knee length dress        1264
# Smart jacket / coat      1147
# Casual jacket / coat      932
# Sleeveless                852
# Jumper                    674
# Blouse                    669
# Jeans                     658
# Evening dress             555
# Cardigan                  486
# Mini dress                466
# Cocktail dress            462
# Short sleeved shirt       416
# Sleeveless top            402
# Knee length skirt         401
# T-Shirt                   394
# Short                     357
# Long dress                354
# Calf length dress         347
# Strapless dress           324
# Skirt                     303
# Blazer                    302
# Dress                     298
# Full length dress         282
# Mini skirt                246
# Calf length skirt         245
# Pencil skirt              205
# Coat                      182
# Raincoat                  178
# Sweater                   169
# Long skirt                150
# Polo shirt                144
# Skirt suit                135
# Smock top                 133
# Vest                      133
# Jumpsuit                  128
# Short sleeved T-shirt     127
# Cropped trousers          122
# Sweatshirt                118
# Hoodie                     96
# Leather jacket             86
# Waistcoat                  84
# Bomber jacket              76
# Smock                      66
# Chinos                     60
# Top                        60
# Jeggings                   57
# Pants                      53
# Overcoat                   49
# T-shirt                    39
# Shirt                      33
# Cargo pants                30
# Cargo shorts               27
# Trenchcoat                 23
# Leggings                   22
# Gilet                      17
# Long sleeved T-shirt       15
# Name: Type, dtype: int64

# %%
# listing how many types are left

len(data.Type.unique())
# Out:
# 60

# %%
# missing values

data.isna().sum()
# Out:
# Type            14080
# Colour            612
# Brand              80
# Exact Colour    17306
# Title           29422
# Img name            0
# dtype: int64

# %%
data[data['Colour'].isna()]
# Out:
#            Type Colour                        Brand       Exact Colour  \
# 17          NaN    NaN                 M&amp;S Kids               Pink
# 96     Cardigan    NaN         Unbranded Hand Knit               Lilac
# 100         NaN    NaN                     New Look               Blue
# 111         NaN    NaN                      Monsoon              White
# 112         NaN    NaN                     DK House               Pink
# 113         NaN    NaN                      H&amp;M              Black
# 169         NaN    NaN  M&amp;S Marks &amp; Spencer                red
# 474         NaN    NaN  M&amp;S Marks &amp; Spencer               Blue
# 528         NaN    NaN            Converse All star              Green
# 544         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 573         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 574         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 575         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 585         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 586         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 587         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 588         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 589         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 590         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 603         NaN    NaN  M&amp;S Marks &amp; Spencer              Black
# 605    Trousers    NaN  M&amp;S Marks &amp; Spencer              black
# 788         NaN    NaN                  Gold marked               Gold
# 794         NaN    NaN           Vintage Army Issue              Black
# 818         NaN    NaN                 Blue Harbour               grey
# 821         NaN    NaN     Abercrombie &amp; Fitch               Green
# 823         NaN    NaN                    Hugo Boss               Blue
# 824         NaN    NaN                Ultramagnetic              White
# 840         NaN    NaN                        Musto              Brown
# 841         NaN    NaN                         Gill              Black
# 846         NaN    NaN               Tommy Hilfiger              White
# ...         ...    ...                          ...                ...
# 16051       NaN    NaN                 Karen Millen     Black And Grey
# 16122       NaN    NaN          Dolce &amp; Gabbana             Indigo
# 16865       NaN    NaN                          NaN                NaN
# 818    HD_200028429_01.jpg?v=1
# 821    HD_200028626_01.jpg?v=1
# 823    HD_200028611_01.jpg?v=1
# 824    HD_200028605_01.jpg?v=1
# 840    HD_200028385_01.jpg?v=1
# 841    HD_200028360_01.jpg?v=1
# 846    HD_200028301_01.jpg?v=1
# ...                        ...
# 16051  HD_200012944_01.jpg?v=1
# 16122  HD_200012883_01.jpg?v=1
# 16865  HD_200012068_01.jpg?v=1
# 17164  HD_101862157_01.jpg?v=1
# 17184  HD_200011797_01.jpg?v=1
# 17329  HD_200011606_01.jpg?v=1
# 17759  HD_200010994_01.jpg?v=1
# 18708  HD_200009995_01.jpg?v=1
# 18714  HD_200009994_01.jpg?v=1
# 18716  HD_200009992_01.jpg?v=1
# 20076  HD_200008417_01.jpg?v=1
# 20749  HD_200007501_01.jpg?v=1
# 20764  HD_200007400_01.jpg?v=1
# 21506  HD_200005963_01.jpg?v=1
# 21527  HD_200006139_01.jpg?v=1
# 21772  HD_200006296_01.jpg?v=1
# 22278  HD_200005518_01.jpg?v=1
# 23110  HD_200004448_01.jpg?v=1
# 23111  HD_200004447_01.jpg?v=1
# 24824  HD_200002824_01.jpg?v=1
# 25356  HD_200002361_01.jpg?v=1
# 26008  HD_200001946_01.jpg?v=1
# 26022  HD_200001935_01.jpg?v=1
# 26024  HD_200001850_01.jpg?v=1
# 26192  HD_200001756_01.jpg?v=1
# 26269  HD_200001450_01.jpg?v=1
# 26452  HD_200001364_01.jpg?v=1
# 26659  HD_200001341_01.jpg?v=1
# 27102  HD_200000889_01.jpg?v=1
# 27106  HD_200000880_01.jpg?v=1
#
# [612 rows x 6 columns]

# %%
# if the "colour" column has a missing value we want to fill 
# in it with a known value in the "Exact colour" column

data.Colour.fillna(data['Exact Colour'], inplace=True)
data[data['Colour'].isna()]
# Out:
#       Type Colour      Brand Exact Colour  \
# 9226   NaN    NaN  Unbranded          NaN
# 9530   NaN    NaN        NaN          NaN
# 9606   NaN    NaN        NaN          NaN
# 9720   NaN    NaN        NaN          NaN
# 9774   NaN    NaN        NaN          NaN
# 9777   NaN    NaN        NaN          NaN
# 9796   NaN    NaN        NaN          NaN
# 10651  NaN    NaN      Other          NaN
# 10755  NaN    NaN  Unbranded          NaN
# 11110  NaN    NaN        NaN          NaN
# 11299  NaN    NaN        NaN          NaN
# 11328  NaN    NaN        NaN          NaN
# 11342  NaN    NaN        NaN          NaN
# 11530  NaN    NaN        NaN          NaN
# 11582  NaN    NaN        NaN          NaN
# 11583  NaN    NaN  Unbranded          NaN
# 11586  NaN    NaN        NaN          NaN
# 11946  NaN    NaN        NaN          NaN
# 11954  NaN    NaN      Other          NaN
# 12142  NaN    NaN      Other          NaN
# 12822  NaN    NaN        NaN          NaN
# 13716  NaN    NaN      Other          NaN
# 13959  NaN    NaN        NaN          NaN
# 14262  NaN    NaN        NaN          NaN
# 14319  NaN    NaN      Other          NaN
# 15572  NaN    NaN        NaN          NaN
# 15573  NaN    NaN        NaN          NaN
# 15574  NaN    NaN        NaN          NaN
# 22278  HD_200005518_01.jpg?v=1

# %%
data.isna().sum()
# Out:
# Type            14080
# Colour             32
# Brand              80
# Exact Colour    17306
# Title           29422
# Img name            0
# dtype: int64

# %%
# we will drop all rows that contain a missing value in the "Colour" 
# column since we can't possibly know from the other columns which
# colour it might be

data = data[data['Colour'].notna()]
data.isna().sum()
# Out:
# Type            14048
# Colour              0
# Brand              57
# Exact Colour    17274
# Title           29421
# Img name            0
# dtype: int64

# %%
# return (rows, columns)

data.shape
# Out:
# (35348, 6)

# %%
data[data['Brand'].isna()]
# Out:
#       Type          Colour Brand Exact Colour  \
# 2131   NaN            Grey   NaN          NaN
# 2193   NaN          Silver   NaN          NaN
# 3406   NaN       Metallics   NaN          NaN
# 9263   NaN             Red   NaN          NaN
# 9271   NaN             Red   NaN          NaN
# 9429   NaN  Multi-coloured   NaN          NaN
# 9941   NaN       Metallics   NaN          NaN
# 9942   NaN       Metallics   NaN          NaN
# 10077  NaN             Red   NaN          NaN
# 10078  NaN           Cream   NaN          NaN
# 10888  NaN  Multi-coloured   NaN          NaN
# 11121  NaN       Metallics   NaN         Gold
# 11125  NaN   Cream / ivory   NaN          NaN
# 11129  NaN  Multi-coloured   NaN          NaN
# 11130  NaN       Metallics   NaN          NaN
# 11437  NaN  Multi-coloured   NaN          NaN
# 11682  NaN           Black   NaN          NaN
# 11741  NaN  Multi-coloured   NaN          NaN
# 11858  NaN       Metallics   NaN          NaN
# 11964  NaN       Metallics   NaN          NaN
# 12711  NaN   Cream / ivory   NaN          NaN
# 12719  NaN       Metallics   NaN     Diamante
# 13072  NaN       Metallics   NaN          NaN
# 13161  NaN            Grey   NaN          NaN
# 13286  NaN  Multi-coloured   NaN          NaN
# 13511  NaN            Grey   NaN          NaN
# 13580  NaN  Multi-coloured   NaN          NaN
# 13794  NaN            Blue   NaN          NaN
# 13806  NaN           Brown   NaN          NaN
# 13849  NaN       Metallics   NaN          NaN
# 14234  NaN       Metallics   NaN          NaN
# 14625  NaN          Purple   NaN          NaN
# 14714  NaN            Grey   NaN          NaN
# 14904  NaN       Metallics   NaN          NaN
# 15021  NaN             Red   NaN          NaN
# 15638  NaN          Purple   NaN          NaN
# 15639  NaN          Purple   NaN          NaN
# 15640  NaN          Purple   NaN          NaN
# 15642  NaN            Blue   NaN          NaN
# 15643  NaN            Blue   NaN          NaN
# 15644  NaN           Beige   NaN          NaN
# 15646  NaN           Beige   NaN          NaN
# 15706  NaN       Metallics   NaN          NaN
# 15862  NaN       Metallics   NaN          NaN
# 17642  NaN   Cream / ivory   NaN          NaN
# 18548  NaN       Metallics   NaN          NaN
# 19417  NaN           Black   NaN          NaN
# 19804  NaN       Metallics   NaN          NaN
# 19805  NaN       Metallics   NaN          NaN
# 19806  NaN       Metallics   NaN          NaN
# 19807  NaN       Metallics   NaN          NaN
# 19808  NaN       Metallics   NaN          NaN
# 21776  NaN           Brown   NaN          NaN
# 22044  NaN             Red   NaN          NaN
# 22275  NaN             Red   NaN          NaN
# 22277  NaN       Metallics   NaN          NaN
# 22279  NaN            Blue   NaN          NaN
#
#                                                    Title  \
# 2131                                                 NaN
# 2193       Sterling silver set of cuff links and tie pin
# 3406                               2 Pairs of Cuff Links
# 9263   NWOT Marks &amp; Spencer 2 Thin Leather Belts ...
# 9271   NWOT Marks &amp; Spencer 2 Thin Leather Belts ...
# 9429           New Poppy multicoloured rectangular scarf
# 9941                                     Silver Bracelet
# 9942                       Silver engraved hinged bangle
# 10077             BURGUNDY KOKO WIG LONG BOB WITH FRINGE
# 10078  BLONDE KOKO WIG LONG HIGHLIGHTED BOB WITH CENT...
# 10888               Mackintosh inspired enamelled brooch
# 11121                 Women's Gold Plated Pyramid Brooch
# 11125                       Women's Washer Drop Earrings
# 11129                         Women's Bead Hoop Earrings
# 11130                  Women's Brass Chain Hoop Earrings
# 11437                                 Pineapple Earrings
# 11682                              Hat Pin 9cm Black End
# 11741                Pretty Multi-coloured Wrap Bracelet
# 11858                      Black and White Wrap Bracelet
# 11964                                    Silver bracelet
# 12711                       Unbranded Shell Star Brooch
# 12719                      BNWT Lipsy Diamante Ear Rings
# 13072                  Vintage Stretch Diamante Bracelet
# 13161        Calvin Klein Jeans size M Grey Leather Belt
# 13286                              Choker Style Necklace
# 13511                            One Love Animals Wallet
# 13580                                  Buckle, cloisonne
# 13794                       Leonard Geometric Silk Scarf
# 13806               Jane Shilton Geometric Italian Scarf
# 13849                                    Double necklace
# 14234                   Camilia 925 with Swaroski charms
# 14625                                      Long necklace
# 14714                                                NaN
# 14904                  Silvery Heart Bracelet/ Necklace
# 15021                            Buckingham Orchid Booch
# 15638                    Handmade Purple Print Scrunchie
# 15639                    Handmade Purple Print Scrunchie
# 15640                    Handmade Purple Print Scrunchie
# 15642                 Handmade Blue Bird Print Scrunchie
# 15643                 Handmade Blue Bird Print Scrunchie
# 15644                   Handmade Leopard Print Scrunchie
# 15646                   Handmade Leopard Print Scrunchie
# 15706  The NZ Classic Koru Heart Necklace &amp; Earrings
# 15862                   Zoo Silver Wire Pierced Earrings
# 17642              Unbranded Patterned Silk Square Scarf
# 18548                       Vintage Marcasite Bow Brooch
# 19417                          Smiffys Bat Cape and Mask
# 19804                             2 - Enamelled Brooches
# 19805  NEW Job Lot of 3 pairs of earrings for pierced...
# 19806    Job Lot Braclets 1 - River Island 1 - Unbranded
# 19807                         NEW Gold Tone Lapel Brooch
# 19808                             Job lot of 3 bracelets
# 21776                                                NaN
# 22044                      Yellow Floral Handmade Pouch
# 22275                 Job Lot of 6 Red and Brown Bangles
# 22277                      NEW ASOS Rhinestone Lapel Pin
# 22279                             Job Lot of 2 Bracelets
#
#                       Img name
# 2131   HD_200014675_01.jpg?v=1
# 2193   HD_200014145_01.jpg?v=1
# 3406   HD_200008857_01.jpg?v=1
# 9263   HD_200028991_01.jpg?v=1
# 9271   HD_200028976_01.jpg?v=1
# 9429   HD_200028506_01.jpg?v=1
# 9941   HD_200027517_01.jpg?v=1
# 9942   HD_200027510_01.jpg?v=1
# 10077  HD_200027017_01.jpg?v=1
# 10078  HD_200027028_01.jpg?v=1
# 10888  HD_200024750_01.jpg?v=1
# 11121  HD_200024053_01.jpg?v=1
# 11125  HD_200024042_01.jpg?v=1
# 11129  HD_200024037_01.jpg?v=1
# 11130  HD_200024026_01.jpg?v=1
# 11437  HD_200023127_01.jpg?v=1
# 11682  HD_200022406_01.jpg?v=1
# 11741  HD_200022301_01.jpg?v=1
# 11858  HD_200022050_01.jpg?v=1
# 11964  HD_200021715_01.jpg?v=1
# 12711  HD_200019657_01.jpg?v=1
# 12719  HD_200019626_01.jpg?v=1
# 13072  HD_200018573_01.jpg?v=1
# 13161  HD_200018451_01.jpg?v=1
# 13286  HD_200018285_01.jpg?v=1
# 13511  HD_200016862_01.jpg?v=1
# 13580  HD_200017569_01.jpg?v=1
# 13794  HD_200017064_01.jpg?v=1
# 13806  HD_200017032_01.jpg?v=1
# 13849  HD_200016948_01.jpg?v=1
# 14234  HD_200013683_01.jpg?v=1
# 14625  HD_200014898_01.jpg?v=1
# 14714  HD_200014675_01.jpg?v=1
# 14904  HD_200013320_01.jpg?v=1
# 15021  HD_200014023_01.jpg?v=1
# 15638  HD_200013404_01.jpg?v=1
# 15639  HD_200013403_01.jpg?v=1
# 15640  HD_200013402_01.jpg?v=1
# 15642  HD_200013398_01.jpg?v=1
# 15643  HD_200013397_01.jpg?v=1
# 15644  HD_200013395_01.jpg?v=1
# 15646  HD_200013393_01.jpg?v=1
# 15706  HD_200013317_01.jpg?v=1
# 15862  HD_200013218_01.jpg?v=1
# 17642  HD_200011180_01.jpg?v=1
# 18548  HD_200010064_01.jpg?v=1
# 19417  HD_200009280_01.jpg?v=1
# 19804  HD_200008864_01.jpg?v=1
# 19805  HD_200008853_01.jpg?v=1
# 19806  HD_200008851_01.jpg?v=1
# 19807  HD_200008860_01.jpg?v=1
# 19808  HD_200008856_01.jpg?v=1
# 21776  HD_101827339_01.jpg?v=1
# 22044  HD_200005876_01.jpg?v=1
# 22275  HD_200005524_01.jpg?v=1
# 22277  HD_200005509_01.jpg?v=1
# 22279  HD_200005522_01.jpg?v=1

# %%
# we will drop all rows that have a missing value in the "Brand" 
# column since most of those rows belong in the accessories category

data = data[data['Brand'].notna()]

# %%
data.isna().sum()
# Out:
# Type            13991
# Colour              0
# Brand               0
# Exact Colour    17219
# Title           29418
# Img name            0
# dtype: int64

# %%
data.shape
# Out:
# (35291, 6)

# %%
# Since we can't possibly figure out the type from the other columns 
# except for the "Title" column, we will drop all rows that contain 
# a missing value in both the "Type" column and in the "Title" column

data = data.dropna(subset=["Type", "Title"], how='all')
data.isna().sum()
# Out:
# Type             2350
# Colour              0
# Brand               0
# Exact Colour     8939
# Title           17777
# Img name            0
# dtype: int64

# %%
data.shape
# Out:
# (23650, 6)

# %%
# returning all rows where the "Type" column is missing to check 
# how the "Title" column is

data[data['Type'].isna()]
# Out:
#       Type          Colour                        Brand        Exact Colour  \
# 1      NaN            Pink                    Patagonia     Pink and Yellow
# 2      NaN  Multi-coloured              Sidewalk Sports          Black/Pink
# 4      NaN            Grey                  Alpinestars                 NaN
# 5      NaN            Pink                       Shredz                Pink
# 7      NaN          Purple                     Trespass              Purple
# 10     NaN             Red                          Gap                 Red
# 11     NaN           Brown                    Miss Evie               Brown
# 12     NaN             Red                        Other                 NaN
# 17     NaN            Pink                 M&amp;S Kids                Pink
# 19     NaN             Red                M&amp;S Girls                 Red
# 22     NaN           Brown  M&amp;S Marks &amp; Spencer               Brown
# 23     NaN           Brown  M&amp;S Marks &amp; Spencer               Brown
# 24     NaN           Cream  M&amp;S Marks &amp; Spencer               Cream
# 25     NaN           Cream  M&amp;S Marks &amp; Spencer               Cream
# 26     NaN           Brown  M&amp;S Marks &amp; Spencer               Brown
# 27     NaN            Pink                  Lelli Kelly                Pink
# 28     NaN           White             Little Miss Pink               White
# 29     NaN            Pink                 M&amp;S Kids           Rose pink
# 30     NaN            Grey                           Tu                Grey
# 31     NaN           Black            Converse All star               Black
# 32     NaN            Grey                  Vertbaudet        Charcoal grey
# 49     NaN           White  M&amp;S Marks &amp; Spencer               Clear
# 50     NaN            Blue  M&amp;S Marks &amp; Spencer                Blue
# 51     NaN            Blue  M&amp;S Marks &amp; Spencer                Blue
# 52     NaN            Blue  M&amp;S Marks &amp; Spencer                Blue
# 53     NaN           Black  M&amp;S Marks &amp; Spencer               Black
# 54     NaN           Black  M&amp;S Marks &amp; Spencer               Black
# 55     NaN            Blue  M&amp;S Marks &amp; Spencer                Blue
# 56     NaN            Blue  M&amp;S Marks &amp; Spencer                Blue
# 58     NaN            Pink  M&amp;S Marks &amp; Spencer                Pink
# ...    ...             ...                          ...                 ...
# 27266  NaN          Yellow                  Maya Deluxe        Lemon Yellow
# 27267  NaN            Blue    Anthony Burrill for Oxfam    Blue &amp; Black
# 27268  NaN            Blue    Anthony Burrill for Oxfam    Blue &amp; Black
# 27273  NaN           Brown                        Reiss                Mink
# 27274  NaN            Blue    Anthony Burrill for Oxfam    Blue &amp; White
# 27275  NaN           White    Anthony Burrill for Oxfam   White &amp; Black
# 27278  NaN           Green    Anthony Burrill for Oxfam   Green &amp; Black
# 27280  NaN           White    Anthony Burrill for Oxfam   White &amp; Black
# 27281  NaN           Green    Anthony Burrill for Oxfam   Green &amp; Black
# 27282  NaN            Blue    Anthony Burrill for Oxfam    Blue &amp; Black
# 27284  NaN           White    Anthony Burrill for Oxfam   White &amp; Black
# 27285  NaN           White    Anthony Burrill for Oxfam   White &amp; Black
# 27286  NaN          Yellow    Anthony Burrill for Oxfam  Yellow &amp; Black
# 27287  NaN          Yellow    Anthony Burrill for Oxfam  Yellow &amp; Black
# 27288  NaN   Cream / ivory    Anthony Burrill for Oxfam   Cream &amp; Black
# 27304  NaN          Orange    Anthony Burrill for Oxfam  Orange &amp; Black
# 27306  NaN            Blue    Anthony Burrill for Oxfam    Blue &amp; White
# 27307  NaN       Metallics                    Warehouse              Silver
# 27357  NaN           Green                      Monsoon               green
# 27419  NaN           Black                   Jan Robert               Black
# 27284  HD_200000685_01.jpg?v=1
# 27285  HD_200000682_01.jpg?v=1
# 27286  HD_200000681_01.jpg?v=1
# 27287  HD_200000680_01.jpg?v=1
# 27288  HD_200000678_01.jpg?v=1
# 27304  HD_200000676_01.jpg?v=1
# 27306  HD_200000671_01.jpg?v=1
# 27307  HD_200000603_01.jpg?v=1
# 27357  HD_200000544_01.jpg?v=1
# 27419  HD_200000540_01.jpg?v=1
# 27669  HD_200000275_01.jpg?v=1
# 27847  HD_200000084_01.jpg?v=1
# 28211  HD_101765371_01.jpg?v=1
# 33524  HD_101654661_01.jpg?v=1
# 33605  HD_101513117_01.jpg?v=1
# 34118  HD_101417265_01.jpg?v=1
# 34396  HD_101417126_01.jpg?v=1
# 36776  HD_101510112_01.jpg?v=1
# 36954  HD_101491720_01.jpg?v=1
# 38866  HD_101301404_01.jpg?v=1
#
# [2350 rows x 6 columns]

# %%
# we found some rows that we didn't want by looking at the "Title" 
# column, we will drop all rows that match partially on a string 
# that we don't want

subsetOfItemsToRemove = ['Shoe', 'Tie', 'Ski Trouser', 'Trainer', 'Scarf', 'Links', 'Mittens', 'Loafer', 'Slipper', 
                         'Sandal', 'Bag', 'Bracelet', 'Belt', 'Boot', 'slip on', 'Watch', 'Pumps', 'glasses', 
                         'Chain', 'suit', 'Salopettes', "Gloves", "Cap", "Gaiters", "Handkerchief", "Joggers", 
                         "Brogues", "Pouch", "Heels", "Earrings", "Pyjamas", "Beige", "Poncho", "Purse", "Necklace", 
                         "Mules", "Stilettoes", "Parka", "Gown", "Ring", "Hat", "Brooch", "Bra", "Uniform", "Heel"]

for item in subsetOfItemsToRemove:
    data = data[~data.Title.str.contains(item, na=False, flags=re.IGNORECASE)]
    
data.isna().sum()
# Out:
# Type             1442
# Colour              0
# Brand               0
# Exact Colour     8841
# Title           17777
# Img name            0
# dtype: int64

# %%
data.shape
# Out:
# (22360, 6)

# %%
# By looking at the "Title" column, we can see that it contains
# a few values that we have in our "Type" column. We made a list
# of the values and went through them to check if it partially 
# matches a string in the "Title" column, the "Type" column gets
# that value

lst = ["Evening dress", "Long dress", "Full length dress", "Overcoat", "Trenchcoat", "Long sleeved T-shirt","Leggings", 
       "Gilet", "Raincoat", "Sweatshirt", "Waistcoat", "Full length dress", "Sleeveless", "Knee length dress", "Sweater", 
       "Hoodie", "Smock", "Chinos", "T-Shirt", "Cardigan", "Trousers", "Pants", "Dress", "Skirt", "Shirt", "Vest", "Blazer", 
       "Coat", "Top", "Short", "Jeans", "Blouse", "Jumper", "Jacket"]

dataCopy = data[data['Type'].isna()]

for item in lst:
    idxLst = dataCopy[dataCopy.Title.str.contains(item, na=False, flags=re.IGNORECASE)].index.values
    data.loc[idxLst, 'Type'] = item

data.isna().sum()
# Out:
# Type               56
# Colour              0
# Brand               0
# Exact Colour     8841
# Title           17777
# Img name            0
# dtype: int64

# %%
data.shape
# Out:
# (22360, 6)

# %%
data[data['Type'].isna()]
# Out:
#       Type            Colour                        Brand        Exact Colour  \
# 1326   NaN             Black                        Berik  Black &amp; Silver
# 1529   NaN              Grey        Bermans &amp; Nathans                Grey
# 2544   NaN          Grey Mix       Alex Dalgety &amp; Son            Grey Mix
# 2696   NaN          charcoal                Animal onesie            charcoal
# 3052   NaN             Black                BNWT Russell               Black
# 3079   NaN              Grey            Converse All Star                grey
# 5336   NaN              mink                         Gant                mink
# 9238   NaN             White                    Unbranded                 NaN
# 9247   NaN     Cream / ivory                       Jaeger               Cream
# 9337   NaN             Green                  All Saints               Khaki
# 9485   NaN             Black                        Mango               black
# 9536   NaN        Pink/white                 South beach           Pink/white
# 9539   NaN            Purple                 Ralph Lauren              Purple
# 9546   NaN            Purple                       Clarks              Purple
# 9818   NaN             White             Xcess ice skates               White
# 9964   NaN             Black                Melanie Baker               Black
# 10193  NaN              Pink                      Per Una                Pink
# 10210  NaN             Green                        Hobbs               Green
# 10232  NaN             Beige           Limited Collection                Nude
# 10255  NaN               Red                        Other                 NaN
# 10386  NaN           Purple.  M&amp;S Marks &amp; Spencer             Purple.
# 10426  NaN    Multi-coloured                        Other                 NaN
# 10533  NaN    Multi-coloured                        Other                 NaN
# 10535  NaN     Not specified                    Ted Baker                 NaN
# 10580  NaN              Blue  M&amp;S Marks &amp; Spencer           Navy Blue
# 10754  NaN             White                        Other                 NaN
# 10879  NaN    Multi-coloured                    Hand made      metallic brown
# 11086  NaN         Metallics                        Other                 NaN
# 11120  NaN             Black                         Next                 NaN
# 11579  NaN             Black                        Ivriz    Black &amp; gold
# 11649  NaN             Brown  M&amp;S Marks &amp; Spencer               Brown
# 11728  NaN             Brown                    Unbranded                 NaN
# 11901  NaN              Blue                      Per Una                Blue
# 12147  NaN             Brown               Miss Selfridge              Brown
# 12163  NaN              Gold        Pink - Paradox London                Gold
# 12280  NaN         Metallics                        Other     Silver Coloured
# 12412  NaN              Grey         Debenhams Collection                Grey
# 13105  NaN             White    Glit RA Ice Skates size 2               White
# 13864  NaN             Black                        Other                 NaN
# 14089  NaN  grey &amp; ivory                 Laura Ashley    grey &amp; ivory
# 14090  NaN             Black           M&amp;S Collection               black
# 14213  NaN             Brown                        Other                 NaN
# 14225  NaN             Black                        Other                 NaN
# 14281  NaN              Pink                Jessica Graaf                Pink
# 15679  NaN             Black                    Windsmoor               Black
# 15734  NaN     Cream / ivory                Malene Birger               Cream
# 15913  NaN               Red           M&amp;S Collection                 Red
# 15939  NaN             Black                         Dune    Black &amp; Gold
# 15960  NaN               Red                 Laura Ashley                 Red
# 17184  NaN   Turquoise/White                    Palmettos     Turquoise/White
# 18297  NaN             Black       BNWT French Connection         Black/White
# 18403  NaN            Purple               Jen Jen house          plum/purple
# 20789  NaN             White                    Footglove               White
# 23461  NaN              Grey  M&amp;S Marks &amp; Spencer    Grey &amp; White
# 26659  NaN        Autumn mix                    Glamorous          Autumn mix
# 26712  NaN              Gold                      Hotter     Black &amp; Gold
#
#                                                    Title  \
# 1326   Berik Original One Race Leathers   - Collectio...
# 1529   Bermans &amp; Nathans Der Freischutz Costume G...
# 2544   HD_200012513_01.jpg?v=1
# 2696   HD_200011206_01.jpg?v=1
# 3052   HD_200010626_01.jpg?v=1
# 3079   HD_200010494_01.jpg?v=1
# 5336   HD_200000378_01.jpg?v=1
# 9238   HD_200029031_01.jpg?v=1
# 9247   HD_200029000_01.jpg?v=1
# 9337   HD_200028747_01.jpg?v=1
# 9485   HD_200028425_01.jpg?v=1
# 9536   HD_200028340_01.jpg?v=1
# 9539   HD_200028319_01.jpg?v=1
# 9546   HD_200028304_01.jpg?v=1
# 9818   HD_200027836_01.jpg?v=1
# 9964   HD_200027356_01.jpg?v=1
# 10193  HD_200026571_01.jpg?v=1
# 10210  HD_200026186_01.jpg?v=1
# 10232  HD_200026470_01.jpg?v=1
# 10255  HD_200026363_01.jpg?v=1
# 10386  HD_200026055_01.jpg?v=1
# 10426  HD_200025960_01.jpg?v=1
# 10533  HD_200025694_01.jpg?v=1
# 10535  HD_200025685_01.jpg?v=1
# 10580  HD_200025552_01.jpg?v=1
# 10754  HD_200025255_01.jpg?v=1
# 10879  HD_200024840_01.jpg?v=1
# 11086  HD_200024138_01.jpg?v=1
# 11120  HD_200024056_01.jpg?v=1
# 11579  HD_101877775_01.jpg?v=1
# 11649  HD_200022494_01.jpg?v=1
# 11728  HD_200022127_01.jpg?v=1
# 11901  HD_200021930_01.jpg?v=1
# 12147  HD_200020956_01.jpg?v=1
# 12163  HD_200021225_01.jpg?v=1
# 12280  HD_200020803_01.jpg?v=1
# 12412  HD_200020081_01.jpg?v=1
# 13105  HD_200018532_01.jpg?v=1
# 13864  HD_200016914_01.jpg?v=1
# 14089  HD_200016263_01.jpg?v=1
# 14090  HD_200016237_01.jpg?v=1
# 14213  HD_200015939_01.jpg?v=1
# 14225  HD_200015919_01.jpg?v=1
# 14281  HD_200015831_01.jpg?v=1
# 15679  HD_200013379_01.jpg?v=1
# 15734  HD_200013335_01.jpg?v=1
# 15913  HD_200013132_01.jpg?v=1
# 15939  HD_200013077_01.jpg?v=1
# 15960  HD_200013030_01.jpg?v=1
# 17184  HD_200011797_01.jpg?v=1
# 18297  HD_200010539_01.jpg?v=1
# 18403  HD_200010385_01.jpg?v=1
# 20789  HD_200006928_01.jpg?v=1
# 23461  HD_200004284_01.jpg?v=1
# 26659  HD_200001341_01.jpg?v=1
# 26712  HD_200001258_01.jpg?v=1

# %%
# looking at the remaining rows, we can see that the title contains 
# items that we are not interested in having in our dataset

data = data[data['Type'].notna()]

# %%
data.isna().sum()
# Out:
# Type                0
# Colour              0
# Brand               0
# Exact Colour     8829
# Title           17777
# Img name            0
# dtype: int64

# %%
data.shape
# Out:
# (22304, 6)

# %%
# Since the "Exact Colour" and the "Title" columns were only supposed 
# to be used to fill in missing data in other columns we will drop them

data = data.drop(columns=['Exact Colour', "Title"])

# %%
# describe() is used to get statistics about the dataframe

data.describe()
# Out:
#           Type Colour                        Brand                 Img name
# count    22304  22304                        22304                    22304
# unique      59    164                         6339                    22239
# top     Jacket  Black  M&amp;S Marks &amp; Spencer  HD_101852076_01.jpg?v=1
# freq      2716   4745                         2364                        4

# %%
data.Colour.value_counts()
# Out:
# Black                4745
# Blue                 3819
# Grey                 2333
# Multi-coloured       2114
# Brown                1500
# Pink                 1349
# Green                1077
# White                 950
# Red                   895
# Purple                887
# Beige                 844
# Cream / ivory         794
# Orange                302
# Metallics             252
# Yellow                190
# Cream                  19
# Denim                  14
# Burgundy               11
# black                   8
# Navy                    8
# Multicoloured           6
# Bronze                  5
# Black and White         4
# blue                    4
# Black &amp; White       4
# grey                    4
# Dark Grey               4
# Multi coloured          4
# Gold                    3
# Blue and White          3
#                      ...
# Pink &amp; black        1
# Black/white             1
# denim                   1
# Black &amp; Red         1
# Black/Turquoise         1
# BROWN                   1
# Purple Mix              1
# dark teal               1
# Black Silver            1
# Black and white         1
# Pale Blue               1
# Dark grey               1
# Dark Navy               1
# Teal                    1
# Leopard Print           1
# Brown /                 1
# black and gold          1
# Navy / Cerise           1
# Indigo                  1
# Peachy Pink             1
# Black and Red           1
# Bleu                    1
# royal blue              1
# Mustard Yellow          1
# checked                 1
# Not specified           1
# Soft White              1
# Green Mix               1
# Dusky Pink              1
# mustard                 1
# Name: Colour, Length: 164, dtype: int64

# %%
# looking at the colour column it comes clear that we don't want
# some of the rows that contain a colour, we will drop them

subsetOfItemsToRemove = ["striped ", "checked", "Leopard Print", "Not specified", "Tweed", "Wool", "Turquoise", "Colour",
                         "Olive", "Teal", "Peach", "Putty", "Khaki", "Stone", "Taupe", "Oyster", "Cerise", "Coral", "Aqua"]

for item in subsetOfItemsToRemove:
    data = data[~data.Colour.str.contains(item, na=False, flags=re.IGNORECASE)]

# %%
data.Colour.value_counts()
# Out:
# Black                  4745
# Blue                   3819
# Grey                   2333
# Brown                  1500
# Pink                   1349
# Green                  1077
# White                   950
# Red                     895
# Purple                  887
# Beige                   844
# Cream / ivory           794
# Orange                  302
# Metallics               252
# Yellow                  190
# Cream                    19
# Denim                    14
# Burgundy                 11
# Navy                      8
# black                     8
# Bronze                    5
# grey                      4
# Dark Grey                 4
# Black &amp; White         4
# Black and White           4
# blue                      4
# Navy Blue                 3
# Blue and White            3
# Gold                      3
# Silver                    3
# Lilac                     2
#                        ...
# Brown and Ivory           1
# BROWN                     1
# black &amp; gold          1
# Orange and Blue           1
# Brown pinstripe           1
# White Multi               1
# Purple Multi              1
# Silver Grey               1
# raspberry pink            1
# Light Grey                1
# black &amp; red           1
# Green &amp; Black -       1
# black/champagne           1
# Multi Colouerd            1
# Blue &amp; Orange         1
# Black And Grey            1
# green                     1
# Grey &amp; Black          1
# BLACK AND BROWN           1
# brown and cream           1
# Dark Grey/White           1
# Chocolate brown           1
# pink and purple           1
# Lilac mix                 1
# merlot                    1
# Black Metallic            1
# Dark Denim                1
# Light Brown               1
# Charcoal Grey             1
# Purple Mix                1
# Name: Colour, Length: 133, dtype: int64

# %%
# we can also see that some of the colours are spread over multiple
# colours, which is probably due to the fact that the employees of
# Oxfam had a free text instead of a selectable box to input the colour
# We will consolidate these colours into a single colour if it partially
# matches

colourLstBefore = ["Cream / ivory", "amp;", "/", "and", "Multi", "Mutli", "Silver", "Gold", "Bronze", "Metallic", "Black", 
                   "Blue", "Grey", "Brown", "Pink", "Green", "White", "Cream", "Purple", "Red", "Lemon", "Navy", "Mustard", 
                   "Denim", "Plum", "Bleu", "Indigo", "Lilac", "Burgundy", "Merlot", "Camel"]

colourLstAfter = ["Cream", "Multi-coloured", "Multi-coloured", "Multi-coloured", "Multi-coloured", "Multi-coloured", 
                  "Metallics", "Metallics", "Metallics", "Metallics", "Black", "Blue", "Grey", "Brown", "Pink", "Green", 
                  "White", "Cream", "Purple", "Red", "Green", "Blue", "Yellow", "Blue", "Purple", "Blue", "Blue", "Blue", 
                  "Red", "Red", "Brown"]

for index, item in enumerate(colourLstBefore):
    rowIDs = data[data.Colour.str.contains(item, na=False, flags=re.IGNORECASE)].index.values
    data.loc[rowIDs, 'Colour'] = colourLstAfter[index]

# %%
data.Colour.value_counts()
# Out:
# Black        4755
# Blue         3864
# Grey         2345
# Brown        1506
# Pink         1354
# Green        1082
# Red           978
# White         951
# Purple        890
# Beige         844
# Cream         816
# Orange        302
# Metallics     266
# Yellow        192
# Name: Colour, dtype: int64

# %%
data.shape
# Out:
# (20145, 4)

# %%
data.describe()
# Out:
#           Type Colour                        Brand                 Img name
# count    20145  20145                        20145                    20145
# unique      59     14                         5855                    20082
# top     Jacket  Black  M&amp;S Marks &amp; Spencer  HD_101852076_01.jpg?v=1
# freq      2633   4755                         2208                        4

# %%
data.Brand.value_counts()
# Out:
# M&amp;S Marks &amp; Spencer    2208
# Next                            455
# Per Una                         364
# Unbranded                       346
# Ted Baker                       303
# Monsoon                         257
# ASOS                            247
# Jaeger                          222
# Coast                           208
# Laura Ashley                    199
# River Island                    187
# Karen Millen                    183
# H&amp;M                         175
# Zara                            154
# Topshop                         142
# Hobbs                           133
# Phase Eight                     131
# Boden                           131
# Gap                             123
# French Connection               119
# Ralph Lauren                    115
# Reiss                           114
# Debenhams                       113
# M&amp;S Collection              102
# Warehouse                       102
# Burberry                        100
# New Look                         95
# Whistles                         93
# Wallis                           93
# Hugo Boss                        90
#                                ...
# Ultramagnetic                     1
# Lusture                           1
# Offshoot                          1
# INOC                              1
# Viviannes Collection              1
# Hobbs.                            1
# Joules -                          1
# Steilmann                         1
# Lacza Luca                        1
# M&amp;Co Boutique                 1
# Alexander Wang                    1
# Wantthattrend.com                 1
# Express Design Studio             1
# Mohito                            1
# Gio Goi                           1
# Old Navy                          1
# Mad Hero                          1
# M Butterfly                       1
# DEVILS ADVOCATE                   1
# ASOS sample Loaded                1
# South - Heritage                  1
# Set                               1
# Callaway                          1
# Style Unlimited                   1
# Next Signature -                  1
# Urbancode London                  1
# McKenzy outerwear                 1
# Today's Woman                     1
# Green Coast                       1
# Coline                            1
# Name: Brand, Length: 5855, dtype: int64

# %%
# we want to change some brands to Unknown since most of them have
# a low amount of rows and they will interfere with our next step

brandChangeToUnknown = ["AZARA", "Velvet by Graham &amp; Spencer", "East Coast", "Green Coast", "North Coast", 
                        "Tadashi Collection", "Kardashian Kollection for Lipsy", "Dolce Vita", "Big Star", "Arrogant", 
                        "Handmade", "Jacques Britt", "Jacques Sac", "Mylene Klass", "Oaklands", "Rowlands", "Urban Landscape", 
                        "Larry Levine", "Miss levi", "Tahari Arthur S.Levine", "Tahari, Arthur S Levine", "Linea Raffaelli", 
                        "Linea Tesini", "axcess (a Claiborne company)", "Kim &amp; Co", "Love Mango Basic", "Monsoon Fusion", 
                        "Kiwistuff", "Vilagallo", "Vila Joy", "J. Toyner Eromann", "Roman Carter"]

for item in brandChangeToUnknown:
    rowIDs = data[data.Brand.str.contains(item, na=False, flags=re.IGNORECASE)].index.values
    data.loc[rowIDs, 'Brand'] = "Unknown"
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:12: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
# some of the brands are spread over multiple brands, e.g.
# "Marks & Spencer". This is probably due to employees at Oxfam
# having a free text when entering the brand as opposed to having
# a selectable box to input the brand.
# We will consolidate the brands that belong together

brandLstBefore = ["M&amp;S", "M &amp; S", "M and S", "Marks &amp; Spencer", "Unbranded", "H&amp;M", "Armani", "Calvin", 
                  "Laura Ashley", "Jack &amp; Jones", "Marks and Spencer", "Abercombie", "Abercrombie", "Abercrombe", "Zara", 
                  "Dominguez", "Adolfo", "Adidas", "All Saints", "allsaints", "Apricot", "Aquascutum", "ASOS", "Atmosphere", 
                  "Austin Reed", "Autograph", "AX Paris", "AX (Paris)", "Ax, Paris", "Banana", "Barbour", "Ben Sherman", 
                  "Bench", "Benetton", "Betty Barclay", "Betty Jackson", "BHS", "Biba", "Boden", "Boohoo", "Brook Taverner", 
                  "Burberry", "Burton", "Charles Tyrwhitt", "Coast", "Country Casuals", "Cotton Traders", "Daks", "Damart", 
                  "Daniel Hechter", "Daniel Hetcher", "Dannimac", "Dash", "Debenhams", "Debut", "Début", "Furstenberg", 
                  "Diane Von", "Diesel", "DKNY", "Karan", "Gabbana", "Dolce", "Dorothy Perkins", "Eastex", "Edina Ronay", 
                  "Edinburgh", "Escada", "Evans", "EWM", "F&amp;F", "F &amp; F", "F + F", "F+F", "Fat Face", "FatFace", 
                  "Fenn", "Fire Trap", "Forever 21", "Frank Usher", "French Connection", "G Star", "G-Star", "Gant", "Darel", 
                  "Weber", "Bacconi", "Glamorous", "Great Plains", "Guess", "Hobbs", "Hollister", "Hugo Boss", "J Crew", 
                  "J. Crew", "J.Crew", "Jack Wills", "Jack Willis", "Jackpot", "Jacques", "Jacque's Vert", "Jaeger", "Jaegar", 
                  "Jane Norman", "Jasper", "Jeff Banks", "Jigsaw", "Joe Brown", "John Lewis", "Joule", "scope", "Kaliko", 
                  "Karen Millen", "Kenzo", "Klass", "Kook", "Bennett", "Lands", "Land's", "Levi", "Linea", "Lipsy", 
                  "Little Mistress", "Claiborne", "claibonne", "Sally", "Denim &amp; Co", "Denim CO", "Denim and Co", 
                  "M&amp;Co", "M &amp; Co", "Mango", "Marc Jacobs", "Massimo", "Max Mara", "MaxMara", "Mexx", "Michael K", 
                  "Mint Velvet", "Minuet", "Miss Selfridge", "Miss Sixty", "Missguided", "Monsoon", "n Warehouse", "New Look", 
                  "Next", "Nicole Farhi", "Nike", "Oasis", "Costello", "Paul Smith", "Per Una", "Phase Eight", "Cardin", 
                  "Planet", "Ralph Lauren", "Red Herring", "Regatta", "Reiss", "River Island", "John Rocha", "Sandwich", 
                  "St Michael", "Macdonald", "Superdry", "Lewin", "Ted Baker", "Theory", "Thomas Nash", "Timberland", 
                  "Tommy H", "Topman", "Topshop", "Trespass", "Uniqlo", "all mankind", "Laurent", "Yumi", "Wtoo", "Windsmoor", 
                  "Stuff", "Whistles", "Watters", "Warehouse", "Wallis", "Viyella", "Westwood", "Vila", "Versace", "Vera Moda", 
                  "Sainsbury", "TU Clothing", "Tahari", "Steilmann", "Romantica", "Roman", "Rohan", "Cavalli", "Quiz", "Quick", 
                  "Quik", "Pure Collection", "Pull &amp; Bear", "Pull&amp;Bear", "Pull and Bear", "Principles", "Primark", 
                  "Pretty Little Thing", "Prettylittlething", "Precis", "Prada", "Papaya", "Alex &amp; Co", "Alex and Co"]

brandLstAfter = ["Marks & Spencer", "Marks & Spencer", "Marks & Spencer", "Marks & Spencer", "Unknown", "H&M", "Armani", 
                 "Calvin Klein", "Laura Ashley", "Jack & Jones", "Marks & Spencer", "Abercrombie & Fitch", 
                 "Abercrombie & Fitch", "Abercrombie & Fitch", "Zara", "Adolfo Dominguez", "Adolfo Dominguez", "Adidas", 
                 "All Saints", "All Saints", "Apricot", "Aquascutum", "ASOS", "Atmosphere", "Austin Reed", "Autograph", 
                 "AX Paris", "AX Paris", "AX Paris", "Banana Republic", "Barbour", "Ben Sherman", "Bench", "Benetton", 
                 "Betty Barclay", "Betty Jackson", "BHS", "Biba", "Boden", "Boohoo", "Brook Taverner", "Burberry", "Burton", 
                 "Charles Tyrwhitt", "Coast", "Country Casuals", "Cotton Traders", "Daks", "Damart", "Daniel Hechter", 
                 "Daniel Hechter", "Dannimac", "Dash", "Debenhams", "Debut", "Début", "Diane Von Furstenberg", 
                 "Diane Von Furstenberg", "Diesel", "DKNY", "DKNY", "Dolce & Gabbana", "Dolce & Gabbana", "Dorothy Perkins", 
                 "Eastex", "Edina Ronay", "Edinburgh Woollen Mill", "Escada", "Evans", "EWM", "F&F", "F&F", "F&F", "F&F", 
                 "FatFace", "FatFace", "Fenn Wright Manson", "Firetrap", "Forever 21", "Frank Usher", "French Connection", 
                 "G Star", "G Star", "Gant", "Gerard Darel", "Gerry Weber", "Gina Bacconi", "Glamorous", "Great Plains", 
                 "Guess", "Hobbs", "Hollister", "Hugo Boss", "J. Crew", "J. Crew", "J. Crew", "Jack Wills", "Jack Wills", 
                 "Jackpot", "Jacques Vert", "Jacques Vert", "Jaeger", "Jaeger", "Jane Norman", "Jasper Conran", "Jeff Banks", 
                 "Jigsaw", "Joe Browns", "John Lewis", "Joules", "Kaleidoscope", "Kaliko", "Karen Millen", "Kenzo", "Klass", 
                 "Kookai", "L.K. Bennett", "Lands' End", "Lands' End", "Levi's", "Linea", "Lipsy", "Little Mistress", 
                 "Liz Claiborne", "Liz Claiborne", "Long Tall Sally", "Denim & Co", "Denim & Co", "Denim & Co", "M&Co", "M&Co", 
                 "Mango", "Marc Jacobs", "Massimo Dutti", "Max Mara", "Max Mara", "Mexx", "Michael Kors", "Mint Velvet", 
                 "Minuet", "Miss Selfridge", "Miss Sixty", "Missguided", "Monsoon", "Mountain Warehouse", "New Look", "Next", 
                 "Nicole Farhi", "Nike", "Oasis", "Paul Costelloe", "Paul Smith", "Per Una", "Phase Eight", "Pierre Cardin", 
                 "Planet", "Ralph Lauren", "Red Herring", "Regatta", "Reiss", "River Island", "John Rocha", "Sandwich", 
                 "St Michael", "Julien Macdonald", "Superdry", "T.M.Lewin", "Ted Baker", "Theory", "Thomas Nash", "Timberland", 
                 "Tommy Hilfiger", "Topman", "Topshop", "Trespass", "Uniqlo", "7 For All Mankind", "Yves Saint Laurent", 
                 "Yumi", "Wtoo", "Windsmoor", "White Stuff", "Whistles", "Warehouse", "Watters & Watters", "Wallis", "Viyella", 
                 "Vivienne Westwood", "Vila", "Versace", "Vero Moda", "TU","TU", "Tahari", "Steilmann", "Romantica", "Roman", 
                 "Rohan", "Cavalli", "Quiz", "Quiksilver", "Quiksilver", "Pure Collection", "Pull & Bear", "Pull & Bear", 
                 "Pull & Bear", "Principles", "Primark", "PrettyLittleThing", "PrettyLittleThing", "Precis", "Prada", "Papaya", 
                 "Alex & Co", "Alex & Co"]

for index, item in enumerate(brandLstBefore):
    rowIDs = data[data.Brand.str.contains(item, na=False, flags=re.IGNORECASE)].index.values
    data.loc[rowIDs, 'Brand'] = brandLstAfter[index]
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:63: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
# TU was also spread over several values. But since it would partially
# match many non related brands, we decided to do it without partially
# matching
tuList = ["TU", "TU ", "Tu"]
for i in tuList:
    data['Brand'] = data['Brand'].replace(to_replace = i, value = "TU")

# %%
# all brands that have a sub 20 sum of rows will be consolidated
# into the "Unknown" brand since it is not wise to use them in our
# dataset in Google

brandDict = (data.Brand.value_counts()).to_dict()

for key, val in brandDict.items():
    if val < 20:
        data['Brand'] = data['Brand'].replace(to_replace = key, value = "Unknown")

# %%
data.Brand.value_counts()
# Out:
# Unknown               8041
# Marks & Spencer       2441
# Next                   475
# Per Una                375
# Ted Baker              312
# ASOS                   299
# Monsoon                268
# Jaeger                 231
# Coast                  214
# Zara                   212
# Laura Ashley           208
# River Island           202
# Karen Millen           184
# H&M                    183
# F&F                    177
# Ralph Lauren           167
# Watters & Watters      155
# Hobbs                  152
# Topshop                143
# Boden                  138
# Phase Eight            138
# Armani                 136
# French Connection      129
# Debenhams              125
# Gap                    123
# Reiss                  117
# Burberry               115
# Oasis                  111
# New Look               100
# Wallis                  99
#                       ...
# J. Crew                 27
# Jasper Conran           27
# George                  27
# M&Co                    27
# Ben Sherman             26
# Atmosphere              26
# Uniqlo                  26
# Firetrap                26
# Nicole Farhi            25
# Regatta                 25
# PrettyLittleThing       25
# COS                     25
# Linea                   25
# Jack & Jones            23
# Little Mistress         23
# Yves Saint Laurent      23
# Vila                    22
# Frank Usher             22
# Burton                  21
# Adidas                  21
# Rohan                   21
# Apricot                 21
# Mint Velvet             21
# Adini                   21
# Brook Taverner          20
# Prada                   20
# Dannimac                20
# G Star                  20
# Lakeland                20
# Alex & Co               20
# Name: Brand, Length: 129, dtype: int64

# %%
data.describe()
# Out:
#           Type Colour    Brand                 Img name
# count    20145  20145    20145                    20145
# unique      59     14      129                    20082
# top     Jacket  Black  Unknown  HD_101852076_01.jpg?v=1
# freq      2633   4755     8041                        4

# %%
# we can notice from the describe() that the count of "Img name"
# and the unique don't match, which means that there are
# duplicate rows. We will need to remove those rows

data = data.drop_duplicates()
data.describe()
# Out:
#           Type Colour    Brand                 Img name
# count    20082  20082    20082                    20082
# unique      59     14      129                    20082
# top     Jacket  Black  Unknown  HD_200002007_01.jpg?v=1
# freq      2613   4735     7998                        1

# %%
# we will also need to remove the trailing ?v=1 from the Img Name

dataSample = data.sample(1)
sampleIndex = dataSample.index.values.astype(int)[0]

print("Sample row to check: ", sampleIndex)

print("Sample ImgName column before: " + data["Img name"].iloc[sampleIndex])

data["Img name"] = data["Img name"].map(lambda x: x.split("?")[0])

print("Sample ImgName column after: " + data["Img name"].iloc[sampleIndex])
# Out:
# Sample row to check:  11138
# Sample ImgName column before: HD_101828520_01.jpg?v=1
# Sample ImgName column after: HD_101828520_01.jpg

# %%
# Since the scraper only managed to download 16.543 images we will 
# need to remove those rows that don't have an image in our folder

# we used ls >> imagesList.txt in a linux terminal to get a list of
# images in our folder

with open('imagesList.txt', 'r') as f:
    imagesInFolder = [line.strip() for line in f]

data = data[data["Img name"].isin(imagesInFolder)]
    
data.describe()
# Out:
#           Type Colour    Brand             Img name
# count    16543  16543    16543                16543
# unique      59     14      126                16543
# top     Jacket  Black  Unknown  HD_101756728_01.jpg
# freq      2069   4039     7598                    1

# %%
data.Type.value_counts()
# Out:
# Jacket                   2069
# Trousers                 1025
# Smart jacket / coat       943
# Long sleeved shirt        931
# Knee length dress         930
# Casual jacket / coat      751
# Sleeveless                692
# Jeans                     533
# Dress                     513
# Jumper                    494
# Evening dress             481
# Blouse                    428
# Cocktail dress            392
# Cardigan                  392
# Mini dress                374
# Short                     343
# Skirt                     301
# Knee length skirt         301
# Sleeveless top            297
# Strapless dress           292
# Short sleeved shirt       269
# Long dress                263
# Calf length dress         253
# Blazer                    244
# Coat                      230
# Full length dress         207
# T-Shirt                   205
# Mini skirt                162
# Top                       159
# Calf length skirt         151
# Raincoat                  142
# Pencil skirt              140
# Sweater                   120
# Polo shirt                110
# Long skirt                108
# Vest                      105
# Short sleeved T-shirt     104
# Sweatshirt                 93
# Skirt suit                 91
# Hoodie                     91
# Jumpsuit                   88
# Smock top                  85
# Shirt                      83
# Cropped trousers           78
# Leather jacket             75
# Bomber jacket              56
# Smock                      46
# Overcoat                   40
# Pants                      39
# Waistcoat                  39
# Chinos                     28
# Jeggings                   27
# Cargo pants                26
# T-shirt                    26
# Trenchcoat                 18
# Gilet                      17
# Cargo shorts               17
# Leggings                   16
# Long sleeved T-shirt       10
# Name: Type, dtype: int64

# %%
data.Brand.value_counts()
# Out:
# Unknown                7598
# Next                    460
# Ted Baker               307
# ASOS                    295
# Per Una                 280
# Monsoon                 264
# Jaeger                  222
# Coast                   210
# Zara                    206
# River Island            201
# Laura Ashley            196
# Karen Millen            181
# Ralph Lauren            163
# Hobbs                   149
# F&F                     144
# Topshop                 141
# Watters & Watters       136
# Armani                  132
# Boden                   132
# French Connection       129
# Phase Eight             125
# Debenhams               122
# Gap                     121
# Reiss                   115
# Burberry                113
# Oasis                   108
# New Look                 99
# Wallis                   97
# Hugo Boss                96
# DKNY                     92
#                        ...
# J. Crew                  26
# Atmosphere               25
# Ben Sherman              25
# Regatta                  25
# PrettyLittleThing        25
# COS                      25
# Linea                    25
# Jasper Conran            25
# Uniqlo                   24
# George                   24
# Yves Saint Laurent       23
# Little Mistress          23
# Vila                     22
# Nicole Farhi             22
# Frank Usher              22
# Burton                   21
# Mint Velvet              21
# Rohan                    21
# Adidas                   20
# Lakeland                 20
# G Star                   20
# Adini                    20
# Dannimac                 20
# Brook Taverner           19
# Prada                    19
# Apricot                  18
# Marks & Spencer          12
# Abercrombie & Fitch       8
# Dolce & Gabbana           8
# Alex & Co                 4
# Name: Brand, Length: 126, dtype: int64

# %%
data.Colour.value_counts()
# Out:
# Black        4039
# Blue         3067
# Grey         1874
# Brown        1295
# Pink         1151
# Green         923
# Red           796
# Purple        788
# Beige         697
# Cream         662
# White         651
# Metallics     230
# Orange        205
# Yellow        165
# Name: Colour, dtype: int64

# %%
# we can see that some brands now have as low as 4 rows, and
# Marks & Spencer now only has 12 rows, which means that we only
# managed to download 12 images for Marks & Spencer clothing items
# We will consolidate sub 20 brands into the Unknown brand

brandDict = (data.Brand.value_counts()).to_dict()

for key, val in brandDict.items():
    if val < 20:
        data.Brand = data.Brand.replace(to_replace = key, value = "Unknown")

# %%
data.describe()
# Out:
#           Type Colour    Brand             Img name
# count    16543  16543    16543                16543
# unique      59     14      119                16543
# top     Jacket  Black  Unknown  HD_101756728_01.jpg
# freq      2069   4039     7686                    1

# %%
plt.figure(figsize=(16,8))

TypeChart = sns.countplot(
    data=data,
    x='Type'
)

TypeChart.set_xticklabels(TypeChart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))

BrandChart = sns.countplot(
    data=data,
    x='Brand',
    order=data.Brand.value_counts().iloc[:50].index
)


BrandChart.set_xticklabels(BrandChart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))

BrandChart = sns.countplot(
    data=data,
    x='Brand',
    order=data.Brand.value_counts().iloc[1:50].index
)


BrandChart.set_xticklabels(BrandChart.get_xticklabels(), rotation=90)
plt.show()

# %%
plt.figure(figsize=(16,8))

BrandChart = sns.countplot(
    data=data,
    x='Colour'
)

BrandChart.set_xticklabels(BrandChart.get_xticklabels(), rotation=90)
plt.show()

# %%
# printing out the csv that can be formatted for AutoML
data.to_csv(r'Oxfam_Dataset_AutoML.csv')
